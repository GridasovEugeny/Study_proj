# %% [markdown]
# # Оценка результатов A/B-теста recommender_system_test

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# <b>Евгений, привет!👋</b>
#
# Меня зовут Евгений Хоран, я буду ревьюером твоего проекта. Ты можешь обращаться ко мне на "ты"😏 Надеюсь, тебя также не смутит, если я буду обращаться к тебе на "ты", но если это неудобно, обязательно скажи об этом!
#
# Пожалуйста, **не удаляй мои комментарии**, они будут особенно полезны для нашей работы в случае повторной проверки проекта.
#
#
# Также можешь реагировать на мои комментарии своими
#
# Мои комментарии, обозначенны <font color='green'>зеленым</font>, <font color='gold'>желтым</font> и <font color='red'>красным</font> цветами, например:
#
# <br/>
#
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> В случае, если решение на отдельном шаге является полностью правильным.</div>
#
# <br/>
#
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b> В случае, когда решение на отдельном шаге станет еще лучше, если внести небольшие коррективы.
# </div>
#
#
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
#  В случае, когда решение на отдельном шаге требует существенной переработки и внесения правок. Напоминаю, что проект не может быть принят с первого раза, если ревью содержит комментарии, рекомендующие доработать шаги.
# </div>
#
# Увидев у тебя неточность, в первый раз я лишь укажу на ее наличие и дам тебе возможность самому найти и исправить ее. На реальной работе твой руководитель будет поступать также, и я пытаюсь подготовить тебя именно к работе аналитиком. Но если ты пока не справишься с такой задачей - при следующей проверке я дам более точную подсказку!🤓

# %% [markdown]
# <div class="alert alert-info" role="alert">
# <h2>Комментарий студента:<a class="tocSkip"></h2>
#     Преамбула:Хочу обратить внимание, что это второй раз когда я вижу в глаза A\B тест на практике и совершенно не понимаю какой опыт я должен был вынести из этого проекта. В ходе выполенения проекта, полностью потерял мотивацию и местами могут всплывать негативные комментарии, не уверен что удалил их все, местами будет видно, что я делал тяпляп.  Возможно сказалась нехватка времени. По этому, дорогой ревьюер надеюсь это тебя не смутит, этот негатив не имеет никакого отношения к тебе. Буду рад если, где-то сильно ошибся в выводах и не увидел адекватного решения в этом проекте и ты укажешь мне на это. Так же буду рад исправить любые технические ошибки.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
# <b>Все отлично!👍:</b>
#
# Спасибо за объяснение. Прекрасно тебя понимаю, был в похожей ситуации. Постараюсь максимально подробно описать все найденные недочеты, если они встретятся. Надеюсь у нас получится вместе найти силы и мотивацию, чтобы двигаться дальше. Цель очень близка 😉

# %% [markdown]
# Цель проекта:
# * Провести оценку результатов A/B-теста.
# * Оцените корректность проведения теста.
# * Проанализировать результаты теста.
#
# Чтобы оценить корректность проведения теста, необходимо проверить:
# * пересечение тестовой аудитории с конкурирующим тестом;
# * совпадение теста и маркетинговых событий, другие проблемы временных границ теста.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
# Здорово, что во вступлении к твоему проекту есть
#
# * заголовок,
#
# * цель и некоторые задачи проекта
#
# Вступление станет лучше, если ты добавишь в него:
#
# * описание данных,
#
# * твой проект станет намного удобней в использовании, если ты добавишь интерактивное оглавление — с помощью гиперссылок или в плагине toc. Материал об этом есть в студенческом notion, для получения ссылки и доступа обратись к куратору.
#
# Тогда получатель отчета сможет быстрей его понять.
#
#
# </div>

# %%
import math as mth
import pandas as pd
import numpy as np
from scipy import stats as st
import matplotlib
from matplotlib import pyplot as plt
import seaborn as sns

# %%
marketing_events_df = pd.read_csv('/datasets/ab_project_marketing_events.csv')
new_users_df = pd.read_csv('/datasets/final_ab_new_users.csv')
events_df = pd.read_csv('/datasets/final_ab_events.csv')
participants_df = pd.read_csv('/datasets/final_ab_participants.csv')

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# ### Данные маркетинговых событий

# %%
marketing_events_df.sort_values(by='start_dt')
# Out:
#                                 name                   regions    start_dt  \
# 6             Chinese New Year Promo                      APAC  2020-01-25
# 1       St. Valentine's Day Giveaway  EU, CIS, APAC, N.America  2020-02-14
# 8    International Women's Day Promo             EU, CIS, APAC  2020-03-08
# 2             St. Patric's Day Promo             EU, N.America  2020-03-17
# 3                       Easter Promo  EU, CIS, APAC, N.America  2020-04-12
# 7   Labor day (May 1st) Ads Campaign             EU, CIS, APAC  2020-05-01
# 9    Victory Day CIS (May 9th) Event                       CIS  2020-05-09
# 11     Dragon Boat Festival Giveaway                      APAC  2020-06-25
# 4                  4th of July Promo                 N.America  2020-07-04
# 13             Chinese Moon Festival                      APAC  2020-10-01
# 12           Single's Day Gift Promo                      APAC  2020-11-11
# ...

# %%
marketing_events_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   name       14 non-null     object
#  1   regions    14 non-null     object
#  2   start_dt   14 non-null     object
#  3   finish_dt  14 non-null     object
# dtypes: object(4)
# memory usage: 576.0+ bytes

# %% [markdown]
# Необходимо задать правильный формат датам.

# %%
marketing_events_df['start_dt'] = pd.to_datetime(marketing_events_df['start_dt'])
marketing_events_df['finish_dt'] = pd.to_datetime(marketing_events_df['finish_dt'])

# %% [markdown]
# Необходимо привести таблицу к 1 нормальной форме, исправив столбец регионов.

# %%
marketing_events_df['regions'] = marketing_events_df['regions'].str.split(',')
marketing_events_df = marketing_events_df.explode('regions')
marketing_events_df.reset_index(inplace=True,drop=True)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Удачное решение

# %% [markdown]
# ### Данные всех пользоватлей

# %%
new_users_df.sample(5)
# Out:
#                 user_id  first_date     region   device
# 43674  9532BD20A02B4898  2020-12-18  N.America   iPhone
# 34191  4C510B85AC7E487A  2020-12-10         EU       PC
# 40779  B35D679380241207  2020-12-11  N.America  Android
# 34204  758D015419A324A7  2020-12-10         EU   iPhone
# 4749   0467C438FB05FFCB  2020-12-07  N.America  Android

# %%
new_users_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61733 entries, 0 to 61732
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   user_id     61733 non-null  object
#  1   first_date  61733 non-null  object
#  2   region      61733 non-null  object
#  3   device      61733 non-null  object
# dtypes: object(4)
# memory usage: 1.9+ MB

# %% [markdown]
# Необходимо задать правильный формат датам.

# %%
new_users_df['first_date'] = pd.to_datetime(new_users_df['first_date'])

# %% [markdown]
# Все пользователи уникальны по id

# %%
new_users_df['user_id'].nunique()
# Out:
# 61733

# %% [markdown]
# ### Данные событий

# %%
events_df.sample(5)
# Out:
#                  user_id             event_dt    event_name  details
# 122748  5B765EB9460DDF6C  2020-12-28 16:18:31  product_cart      NaN
# 133103  5107BA52FEA4486D  2020-12-09 10:01:33  product_page      NaN
# 132102  5B88229D073808BE  2020-12-09 01:50:14  product_page      NaN
# 106556  58CE08EE5ADB5BA3  2020-12-22 01:49:56  product_cart      NaN
# 373021  3F6B817BBAD660EB  2020-12-21 22:40:51         login      NaN

# %%
events_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 440317 entries, 0 to 440316
# Data columns (total 4 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   user_id     440317 non-null  object
#  1   event_dt    440317 non-null  object
#  2   event_name  440317 non-null  object
#  3   details     62740 non-null   float64
# dtypes: float64(1), object(3)
# memory usage: 13.4+ MB

# %% [markdown]
# Необходимо задать правильный формат датам.

# %%
events_df['event_dt'] = pd.to_datetime(events_df['event_dt'])

# %% [markdown]
# Разбор пропусков в столбце details

# %%
events_df[events_df['details'].isna()]['event_name'].value_counts()
# Out:
# login           189552
# product_page    125563
# product_cart     62462
# Name: event_name, dtype: int64

# %%
events_df[~events_df['details'].isna()]['event_name'].value_counts()
# Out:
# purchase    62740
# Name: event_name, dtype: int64

# %% [markdown]
# Видимо детали события, предусмотрены только для события покупки. Это согласуется с описанием датасета в задании.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Верное наблюдение

# %% [markdown]
# ### Данные участников теста

# %%
participants_df.sample(5)
# Out:
#                 user_id group                  ab_test
# 5944   9E415943B4C0E30F     A  recommender_system_test
# 2035   7972880D60FBF4AC     B  recommender_system_test
# 1428   D6BAFFBE6463E5D8     B  recommender_system_test
# 9843   FFC2CFB58A63BE68     A        interface_eu_test
# 11782  66C5DF0BE14FEA47     B        interface_eu_test

# %%
participants_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18268 entries, 0 to 18267
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   user_id  18268 non-null  object
#  1   group    18268 non-null  object
#  2   ab_test  18268 non-null  object
# dtypes: object(3)
# memory usage: 428.3+ KB

# %% [markdown]
# Некоторые пользователи учавствуют в нескольких тестах

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
# <b>Все отлично!👍:</b>
#
# Важное наблюдение. Возможно стоит удалить таких пользователей, чтобы смежный тест не влиял на наш?
#
# *Если решишь удалять, то стоит произвести удаление не всех пользователей, а только тех которые присутствовали в группе В смежного теста*

# %%
participants_df['user_id'].nunique()
# Out:
# 16666

# %%
participants_df.duplicated().sum()
# Out:
# 0

# %%
participants_df['ab_test'].value_counts()
# Out:
# interface_eu_test          11567
# recommender_system_test     6701
# Name: ab_test, dtype: int64

# %% [markdown]
# Целевые пользователи

# %%
t_participants_df = participants_df[participants_df['ab_test'] == 'recommender_system_test']

# %% [markdown]
# Дубликатов нет

# %%
t_participants_df[t_participants_df['user_id'].duplicated()]
# Out:
# Empty DataFrame
# Columns: [user_id, group, ab_test]
# Index: []

# %% [markdown]
# ## Оценка корректности проведения теста

# %% [markdown]
# Формирую датасет

# %%
t_participants_df = participants_df[participants_df['ab_test'] == 'recommender_system_test'].copy()
t_participants_df.drop('ab_test', axis=1,inplace=True)

# %%
t_participants_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6701 entries, 0 to 6700
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   user_id  6701 non-null   object
#  1   group    6701 non-null   object
# dtypes: object(2)
# memory usage: 157.1+ KB

# %%
t_participants_df = t_participants_df.merge(new_users_df, on='user_id', how='left')

# %%
t_participants_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6701 entries, 0 to 6700
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   user_id     6701 non-null   object
#  1   group       6701 non-null   object
#  2   first_date  6701 non-null   datetime64[ns]
#  3   region      6701 non-null   object
#  4   device      6701 non-null   object
# dtypes: datetime64[ns](1), object(4)
# memory usage: 314.1+ KB

# %%
t_participants_df = t_participants_df.merge(events_df, on='user_id', how='left')

# %%
events_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 440317 entries, 0 to 440316
# Data columns (total 4 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   user_id     440317 non-null  object
#  1   event_dt    440317 non-null  datetime64[ns]
#  2   event_name  440317 non-null  object
#  3   details     62740 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(2)
# memory usage: 13.4+ MB

# %%
t_participants_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27724 entries, 0 to 27723
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   user_id     27724 non-null  object
#  1   group       27724 non-null  object
#  2   first_date  27724 non-null  datetime64[ns]
#  3   region      27724 non-null  object
#  4   device      27724 non-null  object
#  5   event_dt    24698 non-null  datetime64[ns]
#  6   event_name  24698 non-null  object
#  7   details     3331 non-null   float64
# dtypes: datetime64[ns](2), float64(1), object(5)
# memory usage: 1.9+ MB

# %%
#Делаю чистю копию, бы всегда можно было себя проверить
clean_t_participants_df = t_participants_df.copy()

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Правильная практика

# %% [markdown]
# ### Пользователи без событий в системе

# %%
t_participants_df[t_participants_df['event_dt'].isna()]['user_id'].nunique()
# Out:
# 3026

# %% [markdown]
# 3026 уникальных пользователей не имеют зарегистрированных в системе событий

# %% [markdown]
# Проверка этого факта на базовых таблицах

# %%
s1 = participants_df[participants_df['ab_test'] == 'recommender_system_test']['user_id'].unique()

# %%
s2 = events_df['user_id'].unique()

# %% [markdown]
# В таблицах с событиями имеются данные по 3675 пользователям

# %%
len(np.intersect1d(s1, s2))
# Out:
# 3675

# %% [markdown]
# Всего у нас 6701 пользователь и в сумме, пересечение таблицы участников с таблицей событий и пользователи не имеющи событий, дают нам всех пользователей теста.

# %%
t_participants_df[t_participants_df['event_dt'].isna()].shape[0] + len(np.intersect1d(s1, s2))
# Out:
# 6701

# %% [markdown]
# Все сходится этих пользователей изначально небыло в событиях

# %% [markdown]
# По группам потерянные данные распределились не равномерно, группа B пострадала сильней почти в 2 раза.

# %%
t_participants_df[t_participants_df['event_dt'].isna()]['group'].value_counts()
# Out:
# B    1949
# A    1077
# Name: group, dtype: int64

# %% [markdown]
# Проверка того, что каждый пользователь присуствующий в таблицах с событиями залогинился в системе хотя бы раз.

# %%
s1 = t_participants_df[t_participants_df['event_name'] == 'login']['user_id'].unique()
len(s1)
# Out:
# 3675

# %%
s2 = t_participants_df[~t_participants_df['event_dt'].isna()]['user_id'].unique()

# %%
len(np.intersect1d(s1, s2))
# Out:
# 3675

# %% [markdown]
# Проверка даты появления пользователя и даты логирования.

# %%
(t_participants_df[t_participants_df['event_name'] == 'login']['event_dt'] == t_participants_df[t_participants_df['event_name'] == 'login']['first_date']).sum()
# Out:
# 0

# %% [markdown]
# Ни у одного события авторизации пользователя дата не совпадает с датой занесения пользователя в систему. Значит в систему пользователи заносятся по другому принципу.

# %% [markdown]
# Проверка остальных событий на совпадение.

# %%
(t_participants_df['event_dt'] == t_participants_df['first_date']).sum()
# Out:
# 0

# %% [markdown]
# Ни одно события из имеющихся у нас в распоряжении не совпадает с датой занесения пользователя в систему.

# %% [markdown]
# Проверяю предположение о том, что на каждому действию за день предшествует как минимум одна авторизация пльзователя.

# %%
t_participants_df[t_participants_df['event_name'] == 'login']['user_id'].count()
# Out:
# 11190

# %%
t_participants_df[t_participants_df['event_name'] != 'login']['user_id'].count()
# Out:
# 16534

# %% [markdown]
# Тк. данные отсортированные по времени события, первое событие в каждой группе по пользователю и дате должно быть login.

# %%
tmp = t_participants_df.groupby(['user_id',t_participants_df['event_dt'].dt.date])[['event_dt', 'event_name']].first()

# %%
tmp['event_name'].value_counts()
# Out:
# purchase        3331
# product_page    3273
# login           2358
# product_cart    2238
# Name: event_name, dtype: int64

# %% [markdown]
# Предположение не подтвердилось

# %% [markdown]
# #### Промежуточный вывод

# %% [markdown]
# Имеется группа пользователей, отсустсвующая в таблице с событиями. При этом они есть в таблице со всеми пользователями системы и имеют дату первого события. Никакое из имеющися у нас в распоряжении событий не отвечает за дату регистрации пользователя в системе. Так же в таблицах отсутсвует событие отвечающее просто за визит пользователя на сайт, возможно по нему пользователи заносятся в систему и получают первую дату.

# %% [markdown]
# Если считать, что эти пользователи не совершиили ни одного действия т.е например просто посещали сайт не нажимая никуда. То непонятно почему тест был остановлен и признан завершенным, ведь мы не имеет нужного числа пользователей в срезе изучаемых конверсий. Исходя из этого тест уже не корректен.

# %% [markdown]
# Если считать, что произошла ошибка в системе логирования действий пользователя - непонятно зачем я продолжаю работу над этим проектом, ошибка очевидна и ее надо исправить,а затем работать дальше.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Все верно. Ошибку стоит исправить. Однако, не смотря на это мы всегда выполняем свою работу полностью. Мы можем найти еще ошибки или полезные инсайты

# %% [markdown]
# Буду считать пользователей без событий техническим сбоем и не учитывать их при анализе.

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# Это реальный кейс, а не выдуманная фантазером ловушка.
#
# Как мне кажется, лучше сейчас научиться работать с проблемными проектами, чем это произойдет на работе и как итог можно потерпеть убытки и потрепать всем нервы 🙂
#
# Информации в проекте достаточно, чтобы с высокой вероятностью говорить о причинах странного поведения данных, для этого стоит копнуть глубже. Пожалуйста, построй распределение количества уникальных пользователей по дням в разбивке по группам у которых нет событий.

# %% [markdown]
# <div class="alert alert-info" role="alert">
# <h2>Комментарий студента:<a class="tocSkip"></h2>
#     Принять какое то решение исходя из логики ситуации невозможно, явно нехватает информации. Но исходя из опыта размышлений над безсмысленными ловушками для фантазера, полученном мной на этом курсе - выберу менее безсмысленный вариант тк мне еще делать проект, а именно это пользователи не совершившие никаких действий и тест был завершен не набрав нужную выборку по событиям.
#
#
#     Имелось в виду, что фантазер это я. А этот проект это ловушка.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <font color= "black"> V2</font> <a class="tocSkip"> </h2>
# <b>Все отлично!👍 :</b>
#
# Все понятно

# %% [markdown]
# ### Соответствие ТЗ

# %% [markdown]
# Техническое задание
# Название теста: recommender_system_test;
# * Группы: А (контрольная), B (новая платёжная воронка);
# * Дата запуска: 2020-12-07;
# * Дата остановки набора новых пользователей: 2020-12-21;
# * Дата остановки: 2021-01-04;
# * Аудитория: 15% новых пользователей из региона EU;
# * Назначение теста: тестирование изменений, связанных с внедрением улучшенной рекомендательной системы;
# * Ожидаемое количество участников теста: 6000.
# * Ожидаемый эффект: за 14 дней с момента регистрации в системе пользователи покажут улучшение каждой метрики не менее, чем на 10%:
#     * конверсии в просмотр карточек товаров — событие product_page
#     * просмотры корзины — product_cart
#     * покупки — purchase.

# %% [markdown]
# Группы: А (контрольная), B (новая платёжная воронка); ✅ Группы не равные.

# %%
t_participants_df.groupby('group')['user_id'].nunique()
# Out:
# group
# A    3824
# B    2877
# Name: user_id, dtype: int64

# %% [markdown]
# Дата запуска: 2020-12-07; ✅

# %%
t_participants_df['first_date'].min()
# Out:
# Timestamp('2020-12-07 00:00:00')

# %% [markdown]
# Дата остановки набора новых пользователей: 2020-12-21;  ✅

# %%
t_participants_df['first_date'].max()
# Out:
# Timestamp('2020-12-21 00:00:00')

# %% [markdown]
# Дата остановки: 2021-01-04; ❌. Если предполагать, что событий больше небыло в плоть до 01.04 то ✅.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
# <b>Все отлично!👍:</b>
#
# Если событий нет, то это будет как минимум странно🙂 В таком случае появится еще больше работы

# %%
t_participants_df['event_dt'].max()
# Out:
# Timestamp('2020-12-30 12:42:57')

# %% [markdown]
# Аудитория: 15% новых пользователей из региона EU; ✅❌. Процент примерно верный но присутствуют пользователи из других регионов.

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# Мы можем оставить пользователей из других регионов для дальнейшего анализа, но это не наша целевая аудитория. Чтобы подсчитать долю для ТЗ, возможно, стоит убрать пользователей из других регионов?

# %% [markdown]
# <div class="alert alert-info" role="alert">
# <h2>Комментарий студента:<a class="tocSkip"></h2>
#     Согласен, далее они и так исчезают, при фильтрации по лайфтайму.
# </div>

# %%
clean_t_participants_df = t_participants_df
t_participants_df = t_participants_df[t_participants_df['region'] == 'EU']

# %%
"{:.0%}".format(t_participants_df[t_participants_df['region'] == 'EU']['user_id'].nunique()/new_users_df[new_users_df['region'] == 'EU']['user_id'].nunique())
# Out:
# '14%'

# %%
t_participants_df['region'].value_counts()
# Out:
# EU    26290
# Name: region, dtype: int64

# %% [markdown]
# Ожидаемое количество участников теста: 6000. ✅

# %%
t_participants_df['user_id'].nunique()
# Out:
# 6351

# %% [markdown]
# * Ожидаемый эффект: за 14 дней с момента регистрации в системе пользователи покажут улучшение каждой метрики не менее, чем на 10%:
#     * конверсии в просмотр карточек товаров — событие product_page❌
#     * просмотры корзины — product_cart❌
#     * покупки — purchase.❌

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# Было обнаружено:
#
# * часть пользователей из других регионов
# * часть пользователей не имеет событий
#
# Стоит провести фильтрацию по этим пунктам и проверить какая часть пользователей останется

# %% [markdown]
# <div class="alert alert-info" role="alert">
# <h2>Комментарий студента:<a class="tocSkip"></h2>
#     Делаю, на этапе анализа.
# </div>

# %% [markdown]
# Сортирую по пользователям и датам событий

# %%
t_participants_df = t_participants_df.sort_values(by=['user_id', 'event_dt'])

# %% [markdown]
# Расчитываю лайфтайм событий для каждого пользователя, у которого имеются события.

# %%
t_participants_df['lifetime'] = (t_participants_df['event_dt'] - t_participants_df['first_date']).dt.days

# %% [markdown]
# 3026 пользователей не совершивших ни одного события.

# %%
t_participants_df[t_participants_df['lifetime'].isna()]
# Out:
#                 user_id group first_date region   device event_dt event_name  \
# 24080  000ABE35EE11412F     A 2020-12-08     EU       PC      NaT        NaN
# 3101   001C05E87D336C59     A 2020-12-10     EU   iPhone      NaT        NaN
# 13055  003B6786B4FF5B03     A 2020-12-13     EU  Android      NaT        NaN
# 20732  006D4BE0C4EA616F     B 2020-12-10     EU       PC      NaT        NaN
# 25572  007B7DE3A2E44050     B 2020-12-21     EU   iPhone      NaT        NaN
# ...                 ...   ...        ...    ...      ...      ...        ...
# 2805   FFB3F647898BA928     B 2020-12-13     EU       PC      NaT        NaN
# 3955   FFC2C5F898D1245B     B 2020-12-10     EU  Android      NaT        NaN
# 21769  FFC53FD45DDA5EE8     B 2020-12-19     EU   iPhone      NaT        NaN
# 17185  FFE858A7845F005E     A 2020-12-08     EU       PC      NaT        NaN
# 23661  FFED90241D04503F     B 2020-12-08     EU  Android      NaT        NaN
#
#        details  lifetime
# ...

# %% [markdown]
# Беру за горизонт 14 лайфтайм, как указано в ТЗ.

# %%
#clean_t_participants_df = t_participants_df
t_participants_df = t_participants_df[t_participants_df['lifetime'] <=13]

# %% [markdown]
# Размеры когорт расчитываю не считая пользователей с 0 событий.

# %% [markdown]
# <div class="alert alert-info" role="alert">
# <h2>Комментарий студента:<a class="tocSkip"></h2>
#    Исправил.
# </div>

# %%
cohort_sizes = t_participants_df.groupby(['first_date', 'group'])['user_id'].nunique()

# %% [markdown]
# Вычисляю сводные таблицы необходимые для подсчета указанных в тз метрик

# %%
cl_product_page_pivot =\
pd.pivot_table(t_participants_df[t_participants_df['event_name'] == 'product_page'],
               index=['first_date', 'group'],
               columns='lifetime',
               values='user_id',
               aggfunc='count').fillna(0).cumsum(axis=1)

cl_product_cart_pivot =\
pd.pivot_table(t_participants_df[t_participants_df['event_name'] == 'product_cart'],
               index=['first_date', 'group'],
               columns='lifetime',
               values='user_id',
               aggfunc='count').fillna(0).cumsum(axis=1)

cl_purchase_pivot =\
pd.pivot_table(t_participants_df[t_participants_df['event_name'] == 'purchase'],
               index=['first_date', 'group'],
               columns='lifetime',
               values='user_id',
               aggfunc='count').fillna(0).cumsum(axis=1)

# %% [markdown]
# #### Конверсии в просмотр карточек товаров - product_page

# %%
Group_A_conversion = cl_product_page_pivot.xs('A', level=1)/cohort_sizes.xs('A', level=1).values[:,None]
Group_B_conversion = cl_product_page_pivot.xs('B', level=1)/cohort_sizes.xs('B', level=1).values[:,None]

# %% [markdown]
# Вычисляю отношение куммулятивных конверсий к 14 лайфтайму

# %%
cl_product_page_pivot.xs('B', level=1)[13].sum()/cl_product_cart_pivot.xs('A', level=1)[13].sum()
# Out:
# 0.5252011859381618

# %% [markdown]
# 52% вместо ожидаемых 110%, не соответствуют ТЗ.

# %% [markdown]
# Вычисляю отношение конверсий

# %%
_=plt.figure(figsize = (20, 16)) 

_=sns.heatmap(
    np.divide(Group_B_conversion , Group_A_conversion) - 1, annot=True, fmt='.0%'
)

# %% [markdown]
# С большой вероятностью, наши отсуствующие данные по 3к пользователей создают наблюдаемую аномалию

# %% [markdown]
# #### Конверсия в просмотры корзины — product_cart

# %%
Group_A_conversion = cl_product_cart_pivot.xs('A', level=1)/cohort_sizes.xs('A', level=1).values[:,None]
Group_B_conversion = cl_product_cart_pivot.xs('B', level=1)/cohort_sizes.xs('B', level=1).values[:,None]

# %% [markdown]
# Вычисляю отношение куммулятивных конверсий к 14 лайфтайму

# %%
cl_product_cart_pivot.xs('B', level=1)[13].sum()/cl_product_cart_pivot.xs('A', level=1)[13].sum()
# Out:
# 0.26132994493858536

# %% [markdown]
# 26.6% вместо ожидаемых 110%, не соответствуют ТЗ.

# %%
_=plt.figure(figsize = (20, 16)) 

_=sns.heatmap(
    np.divide(Group_B_conversion , Group_A_conversion) - 1, annot=True, fmt='.0%'
)

# %% [markdown]
# С большой вероятностью, наши отсуствующие данные по 3к пользователей создают наблюдаемую аномалию

# %% [markdown]
# #### Конверсия в просмотры корзины — purchase

# %%
Group_A_conversion = cl_purchase_pivot.xs('A', level=1)/cohort_sizes.xs('A', level=1).values[:,None]
Group_B_conversion = cl_purchase_pivot.xs('B', level=1)/cohort_sizes.xs('B', level=1).values[:,None]

# %% [markdown]
# Вычисляю отношение куммулятивных конверсий к 14 лайфтайму

# %%
cl_purchase_pivot.xs('B', level=1)[13].sum()/cl_purchase_pivot.xs('A', level=1)[13].sum()
# Out:
# 0.24869215291750504

# %% [markdown]
# 24% вместо ожидаемых 110%, не соответствуют ТЗ.

# %%
_=plt.figure(figsize = (20, 16)) 

_=sns.heatmap(
    np.divide(Group_B_conversion , Group_A_conversion) - 1, annot=True, fmt='.0%'
)

# %% [markdown]
# С большой вероятностью, наши отсуствующие данные по 3к пользователей создают наблюдаемую аномалию

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
# <b>Некоторые замечания и рекомендации💡:</b>
#
# Если у нас имеются данные, которые приводят к аномальным результатам, стоит убрать такие данные и провести повторный анализ и сравнить результаты. Так твои выводы станут более детальными

# %% [markdown]
# #### Промежуточный вывод

# %% [markdown]
# Техническое задание
# Название теста: recommender_system_test;
# * Группы: А (контрольная), B (новая платёжная воронка);✅
# * Дата запуска: 2020-12-07;✅
# * Дата остановки набора новых пользователей: 2020-12-21;✅
# * Дата остановки: 2021-01-04;✅❌
# * Аудитория: 15% новых пользователей из региона EU;✅❌
# * Назначение теста: тестирование изменений, связанных с внедрением улучшенной рекомендательной системы;✅
# * Ожидаемое количество участников теста: 6000.✅
# * Ожидаемый эффект: за 14 дней с момента регистрации в системе пользователи покажут улучшение каждой метрики не менее, чем на 10%:
#     * конверсии в просмотр карточек товаров — событие product_page❌
#     * просмотры корзины — product_cart❌
#     * покупки — purchase.❌

# %% [markdown]
# Отсутствуют данные о событиях по 3026 уникальным пользователям, участникам теста.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
# <b>Все отлично!👍:</b>
#
# Пункт получился качественный, продемонстрированны интересные решения. В их числе `heatmap`
#
# Шаг можно улучшить выполнив несколько проверок, однако, это не критично, оставляю на твое усмотрение

# %% [markdown]
# ### Корректность времени проведения в отношении промо акций

# %% [markdown]
# Проверяю вхождение любого события в период проведения промо акции в соответствующем регионе.

# %%
tmp = t_participants_df.\
apply(lambda x: list((s.date() <= x['event_dt'].date() <= f.date()) for s,f 
                    in (zip(marketing_events_df[marketing_events_df['regions'] == 'EU']['start_dt'],
                            marketing_events_df[marketing_events_df['regions'] == 'EU']['finish_dt'])))
                   
      , axis=1)

# %%
tmp
# Out:
# 889      [False, False, False, False, False, False, False]
# 886      [False, False, False, False, False, False, False]
# 890      [False, False, False, False, False, False, False]
# 887      [False, False, False, False, False, False, False]
# 891       [True, False, False, False, False, False, False]
#                                ...
# 14327    [False, False, False, False, False, False, False]
# 14330    [False, False, False, False, False, False, False]
# 14334    [False, False, False, False, False, False, False]
# 14328    [False, False, False, False, False, False, False]
# 14331    [False, False, False, False, False, False, False]
# Length: 22620, dtype: object

# %%
tmp.apply(lambda x: np.where(x)[0])
# Out:
# 889       []
# 886       []
# 890       []
# 887       []
# 891      [0]
#         ...
# 14327     []
# 14330     []
# 14334     []
# 14328     []
# 14331     []
# Length: 22620, dtype: object

# %%
tmp.apply(lambda x: np.where(x)[0]).explode().value_counts()
# Out:
# 0    2589
# dtype: int64

# %% [markdown]
# 2589 пересечения событий с 0 по порядку следования(не по индексу) промоакцией в EU

# %%
marketing_events_df[marketing_events_df['regions'] == 'EU'].iloc[0]
# Out:
# name         Christmas&New Year Promo
# regions                            EU
# start_dt          2020-12-25 00:00:00
# finish_dt         2021-01-03 00:00:00
# Name: 0, dtype: object

# %% [markdown]
# Тк пересечение только с 1 акцией сильно заморачиватся с алгоритмом занесения данных в основной датафрейм не стану.

# %%
t_participants_df.loc[:, 'crossing_with_promo'] = tmp.apply(any)

# %%
f2 = t_participants_df['crossing_with_promo'] == True

# %%
t_participants_df[f2]['group'].value_counts()
# Out:
# A    2294
# B     295
# Name: group, dtype: int64

# %% [markdown]
# Эти данные изскажают тест их надо отфильтровать из датафрейма. Добавил фильтр.

# %%
#t_participants_df = t_participants_df[~f2]

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
# <b>На доработку🤔:</b>
#
# Выше мы узнали, что дата остановки теста это 30 число. По таблице видно, что это соответствует одному из событий
#
# ![image.png](attachment:image.png)
#
# Получается, что в алгоритме присутствует ошибка, так как вхождения имеются. Пожалуйста, пересмотри свой алгоритм

# %% [markdown]
# <div class="alert alert-info" role="alert">
# <h2>Комментарий студента:<a class="tocSkip"></h2>
#     Ошибка дуратская(, перепутал лейблы в цикле для стартовой и конечной даты. . .
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <font color= "black"> V2</font> <a class="tocSkip"> </h2>
# <b>Все отлично!👍 :</b>
#
# Не всегда стоит придумывать сложные алгоритмы, если быстрее и проще проверить все глазами и руками, то стоит делать именно так

# %% [markdown]
# 2589 пересечений на фильтрованных данных с Christmas&New Year Promo, на чистых может быть больше. Тест на новогодний период очень странная идея, это конечно не предусмотрено специально.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Очень важное замечание, молодец 🙂

# %% [markdown]
# ### Корректность аудитории теста

# %% [markdown]
# Проверка соотношения групп

# %%
t_participants_df[t_participants_df['lifetime'] <=13].groupby('group')['user_id'].nunique()
# Out:
# group
# A    2604
# B     877
# Name: user_id, dtype: int64

# %% [markdown]
# Пользователи распределенны в группах не равномерно.

# %% [markdown]
# Проверка пересечения групп по пользователям

# %%
s1 = set(t_participants_df[t_participants_df['group'] == 'A']['user_id'].unique())

# %%
s2 = set(t_participants_df[t_participants_df['group'] == 'B']['user_id'].unique())

# %%
len(np.intersect1d(s1, s2))
# Out:
# 0

# %% [markdown]
# Пересечений нет на этом, этот этап корректен.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Верные алгоритмы

# %% [markdown]
# ## EDA

# %% [markdown]
# #### Дополнительный анализ аномальных пользователей.

# %%
f1 = clean_t_participants_df['event_dt'].isna()
#f2 фильтр по промо акциям. он уже применен
f3 = clean_t_participants_df['region'] != 'EU'

clean_t_participants_df[f1&f3]
# Out:
#                 user_id group first_date     region   device event_dt  \
# 26298  8CB01194A7A8B2C6     B 2020-12-10  N.America  Android      NaT
# 26299  E93E75B64A774E02     B 2020-12-17  N.America       PC      NaT
# 26300  ECE67C0C773DCA8F     B 2020-12-09  N.America  Android      NaT
# 26301  01E9662F25EE4560     B 2020-12-17        CIS       PC      NaT
# 26311  7C22AEB8C217EC8D     B 2020-12-14        CIS  Android      NaT
# ...                 ...   ...        ...        ...      ...      ...
# 27640  B5C6C830427BA3F3     A 2020-12-07  N.America  Android      NaT
# 27653  03F889B99919FBF1     A 2020-12-07  N.America  Android      NaT
# 27659  E10D3866C04D7949     B 2020-12-08  N.America   iPhone      NaT
# 27681  CD9752DE672640C1     A 2020-12-08  N.America       PC      NaT
# 27682  CE2208D5C99745E2     B 2020-12-13  N.America  Android      NaT
#
#       event_name  details
# 26298        NaN      NaN
# 26299        NaN      NaN
# 26300        NaN      NaN
# ...

# %% [markdown]
# 156 не из региона EU

# %% [markdown]
# ##### Ползователи без событий

# %%
tmp = clean_t_participants_df[f1].groupby(['group', 'first_date'])['user_id'].nunique().reset_index()

_=plt.figure(figsize = (16, 9)) 


plt.title('Распределение пользователей без событий по датам')
plt.xlabel('Дата')
plt.ylabel('Кол-во пользователей')
_=sns.lineplot(x='first_date', y='user_id', data = tmp , hue='group',  hue_order = ['A', 'B'])

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <font color= "black"> V2</font> <a class="tocSkip"> </h2>
# <b>Все отлично!👍 :</b>
#
# Верный график, молодец 🙂

# %%
clean_t_participants_df[f1].groupby('group')['user_id'].nunique()
# Out:
# group
# A    1077
# B    1949
# Name: user_id, dtype: int64

# %% [markdown]
# ##### Пользователи с событиями

# %%
tmp = clean_t_participants_df[~f1].groupby(['group', 'first_date'])['user_id'].nunique().reset_index()

_=plt.figure(figsize = (16, 9)) 
plt.title('Распределение пользователей с событиями по датам')
plt.xlabel('Дата')
plt.ylabel('Кол-во пользователей')
_=sns.lineplot(x='first_date', y='user_id', data = tmp , hue='group',  hue_order = ['A', 'B'])

# %%
clean_t_participants_df[~f1].groupby('group')['user_id'].nunique()
# Out:
# group
# A    2747
# B     928
# Name: user_id, dtype: int64

# %% [markdown]
# <div class="alert alert-info" role="alert">
# <h2>Комментарий студента:<a class="tocSkip"></h2>
#    Не совсем уверен, что правильно понял, возможно 2020.12.13 произошли какие-то технические неполадки.
# </div>

# %% [markdown]
# Тк в ТЗ нас интересуют данные за 14 лайфтайм, осталяю t_participants_df отфильтрованным по 14 лайфтайму с прошлого этапа.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <font color= "black"> V2</font> <a class="tocSkip"> </h2>
# <b>Все отлично!👍 :</b>
#
# Как раз все наоборот 🙂
#
# До 2020.12.13 были технические неполадки, которые не фиксировали события у части пользователей. После этот баг пофиксили, однако, только в группе А.
#
# Еще одно проблемное место в проведении теста, если не найти эту проблему сейчас, то и следующий тест может оказаться некорректным

# %% [markdown]
# ### Распределение кол-ва событий на пользователя в срезе выборок

# %%
_=plt.figure(figsize = (16, 9)) 

plt.title('Распределение кол-ва событий на пользователя в срезе выборок')
plt.xlabel('Группа')
plt.ylabel('Кол-во пользователей')
_=sns.histplot(x='group', data =t_participants_df, hue='group', hue_order = ['A', 'B'])

# %% [markdown]
# Значильтельный перевес в сторону группы А, как и ожидалось тк. групы не равномерны.

# %% [markdown]
# ### Распределение кол-ва событий по дням в срезе выборок

# %%
tmp = t_participants_df.groupby(['group',t_participants_df['event_dt'].dt.date])['user_id'].count().reset_index()

# %%
_=plt.figure(figsize = (16, 9)) 

plt.title('Распределение кол-ва событий по дням в срезе выборок')
plt.xlabel('Дата')
plt.ylabel('Кол-во пользователей')
_=sns.lineplot(x='event_dt',y='user_id', data = tmp , hue='group',  hue_order = ['A', 'B'])

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b>
#
# * Графики надо доработать. Стоит добавить названия графиков и осей. Для этого у нас есть:
#
# `plt.title('name')`
#
# `plt.xlabel('name')`
#
# `plt.ylabel('name')`
#
# Прикреплю ссылки на официальный сайт
#
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.ylabel.html
#
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.xlabel.html
#
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.title.html
#
#
# Чтобы повернуть подписи на оси нужно использовать `plt.xticks(rotation=45)`
#
# Прикреплю ссылку с примером
#
# https://matplotlib.org/stable/gallery/subplots_axes_and_figures/secondary_axis.html#sphx-glr-gallery-subplots-axes-and-figures-secondary-axis-py
#
# Это очень важно, чтобы твоим коллегам было проще работать с твоими отчетами

# %% [markdown]
# <div class="alert alert-info" role="alert">
# <h2>Комментарий студента:<a class="tocSkip"></h2>
#    Исправил.
# </div>

# %% [markdown]
# Значильтельный перевес в сторону группы А, как и ожидалось тк. групы не равномерны.

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# Это не единственная причина 😉 Как найти вторую причину я писал выше (распределение с пользователями без событий)

# %% [markdown]
# ### Конверсия в воронке

# %%
c_funnel_pivot =\
pd.pivot_table(clean_t_participants_df,
               index='group',
               columns='event_name',
               values='user_id',
               aggfunc='nunique')

# %%
funnel_pivot =\
pd.pivot_table(t_participants_df,
               index='group',
               columns='event_name',
               values='user_id',
               aggfunc='nunique')

# %%
funnel_pivot = funnel_pivot.reindex(columns = ['login', 'product_page', 'product_cart', 'purchase'])
funnel_pivot
# Out:
# event_name  login  product_page  product_cart  purchase
# group
# A            2604          1685           782       833
# B             876           493           244       249

# %%
c_funnel_pivot = c_funnel_pivot[['login', 'product_page', 'product_cart', 'purchase']]
c_funnel_pivot
# Out:
# event_name  login  product_page  product_cart  purchase
# group
# A            2747          1780           824       872
# B             928           523           255       256

# %% [markdown]
# Очевидно, в обоих воронках авторизация не обязательна. Для сравнения вывел воронку по чистому датафрейму, без фильтров.

# %%
s_ = funnel_pivot.shift(1, axis=1)

# %%
s_['login'] = t_participants_df.groupby('group')['user_id'].nunique()

# %%
funnel_pivot = funnel_pivot/s_

# %%
funnel_pivot
# Out:
# event_name    login  product_page  product_cart  purchase
# group
# A           1.00000      0.647081      0.464095  1.065217
# B           0.99886      0.562785      0.494929  1.020492

# %%
_=funnel_pivot.T.plot(figsize=(16,9))
_=plt.title('Конверсия пользователей в воронке')
_=plt.xlabel('Шаг воронки')
_=plt.ylabel('Конверсия')

# %% [markdown]
# Характер конверсии примерно одинаковый. Пользователи группы B чуть лучше переходят в корзину с покупками.

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера <font color= "black"> V2</font> <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# При работе с воронкой всегда стоит добавлять график воронки. Он очень полезен и важен при составлении отчетов.
#
# Вот тут объясняют, как как начертить график воронки:
#
# https://plotly.com/python/funnel-charts

# %% [markdown]
# ###  Динамика конверсии в воронке на разных этапах в срезе выборок

# %%
#Вычисленные ранее сводные таблицы
#cl_product_page_pivot
#cl_product_cart_pivot
#cl_purchase_pivot
#cohort_sizes
#t_participants_df = t_participants_df.merge(events_df, on='user_id', how='left')

# %% [markdown]
# #### Динамика конверсии в просмотр карточек товаров - product_page

# %% [markdown]
# #### Кумулятивный график:

# %%
tmp = t_participants_df[t_participants_df['event_name'] == 'product_page']

tmp = tmp.groupby(['group',tmp['event_dt'].dt.date])['user_id'].count().reset_index()
tmp = tmp.rename({'user_id':'product_page_count'}, axis='columns')

#Расчитываю кумулятивную конверсию в просмотры карточек товара
tmp['q_product_page_count'] = tmp.groupby('group')['product_page_count'].cumsum()

#Расчитываю коммулятивную максимально возможную конверсию согласно имеющимся в системе пользователям на каждую дату.
#Когорты по группам и датам
u_ = t_participants_df.groupby(['group', t_participants_df['first_date'].dt.date])['user_id'].nunique().reset_index().rename({'user_id':'user_count', 'first_date':'event_dt'}, axis='columns')
#Добавляю в основной фрейм чтобы посчитать число пользователей для каждой даты кумулятивно
tmp = tmp.merge(u_, on=['group', 'event_dt'], how='left').fillna(0)
tmp['q_user_count'] = tmp.groupby('group')['user_count'].cumsum()
tmp['q_conv'] = tmp['q_product_page_count']/tmp['q_user_count']

# %%
#tmp

# %%
_=plt.figure(figsize = (16, 9))


plt.title('Кумулятивный график конверсии')
plt.xlabel('Дата')
plt.ylabel('Конверсия')
_=sns.lineplot(x='event_dt', y='q_conv', data=tmp, hue='group',  hue_order = ['A', 'B'])

# %% [markdown]
# Ничего нового группа А больше по событиям и пользователям.

# %% [markdown]
# #### График относительного различия

# %%
tmp_relative = tmp[tmp['group'] == 'B']['q_conv'].values/tmp[tmp['group'] == 'A']['q_conv'].values -1

# %%
tmp_relative[-1]
# Out:
# -0.27551664672012965

# %%
fig, ax = plt.subplots(figsize=(16,9))


plt.title(' График относительного различия')
plt.xlabel('Дата')
plt.ylabel('Конверсия')
_=sns.lineplot(x=tmp['event_dt'].unique(), y=tmp_relative, ax=ax)
_ = ax.axhline(y=0, color='black', linestyle='--')

# %% [markdown]
# Ничего нового группа А больше по событиям и пользователям.

# %% [markdown]
# График выглядит так

# %% [markdown]
# #### Динамика конверсии в просмотр карточек товаров - product_cart

# %% [markdown]
# #### Кумулятивный график:

# %%
tmp = t_participants_df[t_participants_df['event_name'] == 'product_cart']

tmp = tmp.groupby(['group',tmp['event_dt'].dt.date])['user_id'].count().reset_index()
tmp = tmp.rename({'user_id':'product_page_count'}, axis='columns')

#Расчитываю кумулятивную конверсию в просмотры карточек товара
tmp['q_product_page_count'] = tmp.groupby('group')['product_page_count'].cumsum()

#Добавляю в основной фрейм данные когорт чтобы посчитать число пользователей для каждой даты кумулятивно
tmp = tmp.merge(u_, on=['group', 'event_dt'], how='left').fillna(0)
tmp['q_user_count'] = tmp.groupby('group')['user_count'].cumsum()
tmp['q_conv'] = tmp['q_product_page_count']/tmp['q_user_count']

# %%
_=plt.figure(figsize = (16, 9))


plt.title('Кумулятивный график конверсии')
plt.xlabel('Дата')
plt.ylabel('Конверсия')
_=sns.lineplot(x='event_dt', y='q_conv', data=tmp, hue='group',  hue_order = ['A', 'B'])

# %% [markdown]
# Ничего нового

# %% [markdown]
# #### График относительного различия

# %%
tmp_relative = tmp[tmp['group'] == 'B']['q_conv'].values/tmp[tmp['group'] == 'A']['q_conv'].values -1

# %%
tmp_relative[-1]
# Out:
# -0.22405567090071132

# %%
fig, ax = plt.subplots(figsize=(16,9))


plt.title('График относительного различия конверсии')
plt.xlabel('Дата')
plt.ylabel('Конверсия')
_=sns.lineplot(x=tmp['event_dt'].unique(), y=tmp_relative, ax=ax)
_ = ax.axhline(y=0, color='black', linestyle='--')

# %% [markdown]
# Ничего нового

# %% [markdown]
# #### Динамика конверсии в просмотр карточек товаров - purchase

# %% [markdown]
# #### Кумулятивный график:

# %%
tmp = t_participants_df[t_participants_df['event_name'] == 'purchase']

tmp = tmp.groupby(['group',tmp['event_dt'].dt.date])['user_id'].count().reset_index()
tmp = tmp.rename({'user_id':'product_page_count'}, axis='columns')

#Расчитываю кумулятивную конверсию в просмотры карточек товара
tmp['q_product_page_count'] = tmp.groupby('group')['product_page_count'].cumsum()

#Добавляю в основной фрейм данные когорт чтобы посчитать число пользователей для каждой даты кумулятивно
tmp = tmp.merge(u_, on=['group', 'event_dt'], how='left').fillna(0)
tmp['q_user_count'] = tmp.groupby('group')['user_count'].cumsum()
tmp['q_conv'] = tmp['q_product_page_count']/tmp['q_user_count']

# %%
_=plt.figure(figsize = (16, 9))


plt.title('Кумулятивный график конверсии')
plt.xlabel('Дата')
plt.ylabel('Конверсия')
_=sns.lineplot(x='event_dt', y='q_conv', data=tmp, hue='group',  hue_order = ['A', 'B'])

# %% [markdown]
# Ничего нового

# %% [markdown]
# #### График относительного различия

# %%
## Просто дополняю отсутствующую дату, т.к она крайняя и с 0 пользователей не требуется пересчитывать сумму
#tmp = tmp.append({'group':'A','event_dt':pd.to_datetime('2020-12-30').date(),'user_id': 0, 'cumsum':2216}, ignore_index=True)
#tmp = tmp.sort_values(by=['group', 'event_dt']).reset_index(drop=True)


tmp_relative = tmp[tmp['group'] == 'B']['q_conv'].values/tmp[tmp['group'] == 'A']['q_conv'].values -1

# %%
tmp_relative[-1]
# Out:
# -0.26157997012863954

# %%
fig, ax = plt.subplots(figsize=(16,9))


plt.title('График относительного различия конверсии')
plt.xlabel('Дата')
plt.ylabel('Конверсия')
_=sns.lineplot(x=tmp['event_dt'].unique(), y=tmp_relative, ax=ax)
_ = ax.axhline(y=0, color='black', linestyle='--')

# %% [markdown]
# Ничего нового

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b>
#
# Кумулятивные графики это здорово, однако, стоит добавить классический анализ воронки.
#
# Под классическим анализом я имею ввиду:
#
# * построение таблицы с количеством уникальных пользователей на каждом шаге воронки в разбивке по группам
# * расчеты конверсии (сколько пользователей осталось относительно прошлого и первого шагов)
# * построение графика воронки

# %% [markdown]
# <div class="alert alert-info" role="alert">
# <h2>Комментарий студента:<a class="tocSkip"></h2>
#   Исправил выше.
# </div>

# %% [markdown]
# ### Особенности данных

# %% [markdown]
# Группа А имеет большой перевес по кол-ву пользователей в группе в 3 раза и по кол-ву событий на протяжении всего теста, почти в 4 раза.

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# Также можно сообщить о всех найденных проблемах

# %% [markdown]
# ## Оценка  результатов A/B-тестирования

# %% [markdown]
# Тест проведен некорректно группы не равноценны по событиям и размерам аудитории, нарушены условия ТЗ. Если отбросить все это то победила группа А, хотя это безсмысленно.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
# <b>Все отлично!👍:</b>
#
# Наша задача провести анализ и мы его провели. В будущем выбор останется за тобой, проводить анализ или нет.
#
# Однако, на практике обычно проводят анализ, но с оговоркой, что результатам анализа не стоит доверять из-за некорректно проведенного теста и дают рекомендации по его исправлению.

# %% [markdown]
# ### Статистическая разница долей z-критерием

# %%
#t_participants_df уже содержат данные за 14 лайфтаймов, тк отфильтрованы еще в начале.
A = t_participants_df[t_participants_df['group'] == 'A']
B = t_participants_df[t_participants_df['group'] == 'B']

# %% [markdown]
# Кол-во любых возможных конверсий за изучаемый период

# %%
#Беру данные расчитанные в предыдущем задании, тк они корректны оносительно кумулятивной суммы пользователей по датам.
#Складываю всех пользователей по дням что бы получить максимально возможное число конверсий за 14 лайфтаймов
ta = tmp[tmp['group'] == 'A']['q_user_count'].iloc[-1]
tb = tmp[tmp['group'] == 'B']['q_user_count'].iloc[-1]

# %% [markdown]
# #### Конверсия в просмотр карточек товаров - product_page

# %% [markdown]
# Классический уровень статистической значимости 5%.

# %% [markdown]
# H0 - Доли конверсии у воронок А и B одинаковые , H1 -  Доли конверсии у воронок А и B разные

# %%
sa = A[A['event_name'] == 'product_page']['user_id'].nunique()
sb = B[B['event_name'] == 'product_page']['user_id'].nunique()

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b>
#
# Как мне кажется, здесь что-то очень хитрое, но при этом не очень правильное. Если я ошибаюсь подскажи, пожалуйста 🙂
#
# Что я понял:
#
# * таблицы `ta` и `tb` - это сумма кумулятивных показателей (количество пользователей). Мне не совсем понятно, зачем использовать эти показатели. Для `z-критерия` больше подойдет общее количество уникальных пользователей
#
# * таблицы `sa` и `sb` - это количество событий `product_page`
#
# Таким образом получается, что мы используем разные показатели, а именно **количество пользователей** и **количество событий**, что не совсем верно.
# Предлагаю заменить алгоритм построения таблиц `sa` и `sb` так, чтобы считалось количество уникальных пользователей на шаге
#
#     sa = A[A['event_name'] == 'product_page']['user_id'].nunique()
#     sb = B[B['event_name'] == 'product_page']['user_id'].nunique()
#
# Также, обрати внимание, что перед началом проверок стоит добавить
#
# * Какой критерий будет применяться (сделано) и обоснование своего выбора
#
# * Какой уровень значимости будет использован
#
# * Формулировки гипотез
#
# Часть пунктов можно понять из кода, однако, стоит указать их явно

# %% [markdown]
# <div class="alert alert-info" role="alert">
# <h2>Комментарий студента:<a class="tocSkip"></h2>
# По поводу обоснования все просто, критерий прописан в задании(Проверьте статистическую разницу долей z-критерием) именно этот критерий нам показывали в практикуме для сравнения долей, другими методами применительно к долям и z-критерию я не владею.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <font color= "black"> V2</font> <a class="tocSkip"> </h2>
# <b>Все отлично!👍 :</b>
#
# Верное обоснование. Мы будем сравнивать доли, а значит отлично подойдет z-критерий

# %% [markdown]
# <div class="alert alert-info" role="alert">
# <h2>Комментарий студента:<a class="tocSkip"></h2>
# Какой уровень значимости будет использован. Исправил.
# </div>

# %% [markdown]
# <div class="alert alert-info" role="alert">
# <h2>Комментарий студента:<a class="tocSkip"></h2>
#   По поводу того, что я вычисляю, исправил. Я считал долю конверсий 'произошедших по факту' к конверсиям 'теоретически возможным'(в кайждый день теста было n пользователей и могло произойти n конверсий, сумма всех n это сумма всех возможных конверсий).
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <font color= "black"> V2</font> <a class="tocSkip"> </h2>
# <b>Все отлично!👍 :</b>
#
# Понятно, спасибо 🙂

# %%
alpha = .05 # критический уровень статистической значимости

successes = np.array([sa, sb])
trials = np.array([ta, tb])

# пропорция успехов в первой группе:
p1 = successes[0]/trials[0]

# пропорция успехов во второй группе:
p2 = successes[1]/trials[1]

# пропорция успехов в комбинированном датасете:
p_combined = (successes[0] + successes[1]) / (trials[0] + trials[1])

# разница пропорций в датасетах
difference = p1 - p2 

# считаем статистику в ст.отклонениях стандартного нормального распределения
z_value = difference / mth.sqrt(p_combined * (1 - p_combined) * (1/trials[0] + 1/trials[1]))

# задаем стандартное нормальное распределение (среднее 0, ст.отклонение 1)
distr = st.norm(0, 1)

# %%
# считаем статистику в ст.отклонениях стандартного нормального распределения
z_value = difference / mth.sqrt(
    p_combined * (1 - p_combined) * (1 / trials[0] + 1 / trials[1])
)

# задаем стандартное нормальное распределение (среднее 0, ст.отклонение 1)
distr = st.norm(0, 1)

p_value = (1 - distr.cdf(abs(z_value))) * 2

print('p-значение: ', p_value)

if p_value < alpha:
    print('Отвергаем нулевую гипотезу: между долями есть значимая разница')
else:
    print(
        'Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными'
    )
# Out:
# p-значение:  6.942739359416805e-06
# Отвергаем нулевую гипотезу: между долями есть значимая разница

# %%
z_value
# Out:
# 4.495436444894488

# %% [markdown]
# Вероятность получить такую разницу между долями крайне мала 6.942739359416805e-06. Отвергаем нулевую гипотезу и считаем разницу между долями статистически значимой.

# %% [markdown]
# #### Конверсия в просмотр карточек товаров - product_cart

# %% [markdown]
# Классический уровень статистической значимости 5%.

# %% [markdown]
# H0 - Доли конверсии у воронок А и B одинаковые , H1 -  Доли конверсии у воронок А и B разные

# %%
sa = A[A['event_name'] == 'product_cart']['user_id'].nunique()
sb = B[B['event_name'] == 'product_cart']['user_id'].nunique()

# %%
alpha = .05 # критический уровень статистической значимости

successes = np.array([sa, sb])
trials = np.array([ta, tb])

# пропорция успехов в первой группе:
p1 = successes[0]/trials[0]

# пропорция успехов во второй группе:
p2 = successes[1]/trials[1]

# пропорция успехов в комбинированном датасете:
p_combined = (successes[0] + successes[1]) / (trials[0] + trials[1])

# разница пропорций в датасетах
difference = p1 - p2 

# считаем статистику в ст.отклонениях стандартного нормального распределения
z_value = difference / mth.sqrt(p_combined * (1 - p_combined) * (1/trials[0] + 1/trials[1]))

# задаем стандартное нормальное распределение (среднее 0, ст.отклонение 1)
distr = st.norm(0, 1)

# %%
# считаем статистику в ст.отклонениях стандартного нормального распределения
z_value = difference / mth.sqrt(
    p_combined * (1 - p_combined) * (1 / trials[0] + 1 / trials[1])
)

# задаем стандартное нормальное распределение (среднее 0, ст.отклонение 1)
distr = st.norm(0, 1)

p_value = (1 - distr.cdf(abs(z_value))) * 2

print('p-значение: ', p_value)

if p_value < alpha:
    print('Отвергаем нулевую гипотезу: между долями есть значимая разница')
else:
    print(
        'Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными'
    )
# Out:
# p-значение:  0.21469192029582396
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными

# %%
z_value
# Out:
# 1.2407667698576503

# %% [markdown]
# Вероятность случаного получения такой разницы между пропорциями 21 процент. Остаемся при нулевой гипотезе. Доли конверсий в просмотр карточек товаров  в воронках будут одинаковые.

# %% [markdown]
# #### Конверсия в просмотр карточек товаров -  purchase

# %% [markdown]
# Классический уровень статистической значимости 5%.

# %% [markdown]
# H0 - Доли конверсии у воронок А и B одинаковые , H1 -  Доли конверсии у воронок А и B разные

# %%
sa = A[A['event_name'] == 'purchase']['user_id'].nunique()
sb = B[B['event_name'] == 'purchase']['user_id'].nunique()

# %%
alpha = .05 # критический уровень статистической значимости

successes = np.array([sa, sb])
trials = np.array([ta, tb])

# пропорция успехов в первой группе:
p1 = successes[0]/trials[0]

# пропорция успехов во второй группе:
p2 = successes[1]/trials[1]

# пропорция успехов в комбинированном датасете:
p_combined = (successes[0] + successes[1]) / (trials[0] + trials[1])

# разница пропорций в датасетах
difference = p1 - p2 

# считаем статистику в ст.отклонениях стандартного нормального распределения
z_value = difference / mth.sqrt(p_combined * (1 - p_combined) * (1/trials[0] + 1/trials[1]))

# задаем стандартное нормальное распределение (среднее 0, ст.отклонение 1)
distr = st.norm(0, 1)

# %%
# считаем статистику в ст.отклонениях стандартного нормального распределения
z_value = difference / mth.sqrt(
    p_combined * (1 - p_combined) * (1 / trials[0] + 1 / trials[1])
)

# задаем стандартное нормальное распределение (среднее 0, ст.отклонение 1)
distr = st.norm(0, 1)

p_value = (1 - distr.cdf(abs(z_value))) * 2

print('p-значение: ', p_value)

if p_value < alpha:
    print('Отвергаем нулевую гипотезу: между долями есть значимая разница')
else:
    print(
        'Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными'
    )
# Out:
# p-значение:  0.04652482738393027
# Отвергаем нулевую гипотезу: между долями есть значимая разница

# %%
z_value
# Out:
# 1.9906004806163913

# %% [markdown]
# Вероятность получить такую разницу между долями близка к границе уровня статистической значимости  0.04652482738393027. Отвергаем нулевую гипотезу и считаем разницу между долями статистически значимой.

# %% [markdown]
# ## Вывод

# %% [markdown]
# Тест не соответствует некоторым пунктам ТЗ, группы пользователей распределены не равномерно по кол-ву событий и пользователей за 14 лайфтайм :

# %% [markdown]
# Техническое задание
# Название теста: recommender_system_test;
# * Группы: А (контрольная), B (новая платёжная воронка);✅
# * Дата запуска: 2020-12-07;✅
# * Дата остановки набора новых пользователей: 2020-12-21;✅
# * Дата остановки: 2021-01-04;✅❌
# * Аудитория: 15% новых пользователей из региона EU;✅❌
# * Назначение теста: тестирование изменений, связанных с внедрением улучшенной рекомендательной системы;✅
# * Ожидаемое количество участников теста: 6000.✅
# * Ожидаемый эффект: за 14 дней с момента регистрации в системе пользователи покажут улучшение каждой метрики не менее, чем на 10%:
#     * конверсии в просмотр карточек товаров — событие product_page❌
#     * просмотры корзины — product_cart❌
#     * покупки — purchase.❌

# %% [markdown]
# Период тестирования выпал на новый год. Не понятно специально это или нет.

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# Чтобы точно понять в чем проблема напоминаю, стоит рассмотреть распределение пользователей без событий
#
# В остальном замечания верные.
#
# Вывод это конец проекта, будет здорово, если код представленный ниже будет перемещен в один из разделов анализа.

# %% [markdown]
# С большой вероятностью в системе логирования произошел сбой в период с 2020.12.12 - 2020.12.14.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <font color= "black"> V2</font> <a class="tocSkip"> </h2>
# <b>Все отлично!👍 :</b>
#
# Выше я уже описал как интерпетировать наблюдаемые результаты

# %% [markdown]
# Возможно неправильно подобраны изначальные аудитории теста. Так же возможно новая платежная воронка сама по себе отталкивает пользователей и результаты это отражают. Тяжело делать какие либо выводы по сферическому тесту в вакууме, хотя бы информация о структуре этих воронок необходима.

# %% [markdown]
# Если игнорировать несоответствия, группа А победила и разница долей во всех конверсия статистически значима кроме конверсии в переход в корзину. Разница в конверсиях в карточку товара, корзину и покупку по порядку: 28%, 22%, 28%.

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# **Общий вывод по проекту**
#
# Евгений, спасибо за твой проект! Ты показал свои навыки, приложил много сил и довел проект до конца. Заметно, что ты действуешь по плану и соблюдаешь структуру, это здорово.
#
# Твой комментарий в начале проекта меня насторожил, однако, на деле все хорошо. После небольшой доработки, надеюсь у тебя появится понимание проекта. В целом ты верно высказывал свое негодование к качеству данных, они в ужасном состоянии и делать достоверные вывода на их основе нельзя.
#
# Повторюсь, что даже на таких данных стоит выполнять анализ. Это помогает выявить максимум проблем и иногда полезные инсайты.
#
# Чтобы твой проект стал более информативен и стал проще в понимании для закачка в итоговом выводе стоит добавить рекомендации в которых надо указать все найденные проблемы.
#
# Если есть вопросы, задавай. Буду рад ответить на них🙋
#
# Есть несколько важных моментов, которые я отметил и которые можно было бы улучшить, подсказки ты найдешь в моих комментариях.
#
# **Отмечу отдельные положительные моменты проекта🙂**:
#
# * Ты используешь все необходимые для предварительного анализа инструменты!
# * Выполнены все исследования для таблиц из A/B теста
# * Очень четкие и правильные выводы. Они присутствуют везде где должны быть и полностью понятны
# * Отличная структура проекта, за исключением кода после вывода
# * Ты активно используешь визуализацию, хорошо, что ты не избегаешь этого инструмента анализа
# * Выдвинуты возможные причины поведения данных
# * В коде присутствуют комментарии
# * Присутствуют интересные решения
# * Верные замечания к корректности проведения теста
#
# **На что стоит обратить внимание🤓**:
#
# * Оформление графиков
# * Переделать алгоритм поиска событий пересекающихся с праздниками
# * Добавить классический анализ воронки
# * Добавить обоснование выбора какой критерий будет применяться
# * Добавить наблюдение какой уровень значимости будет использован
# * Важно добавить формулировку гипотез
# * Важно переделать алгоритм создания таблиц `ta tb sa sb`
# * Переписать и дополнить выводы, где требуется
# * Остальные рекомендации ты найдешь в моих комментариях!
#
#
# **Желаю удачи и жду твой проект на повторное ревью!**😉
#
# ![gif](https://media.giphy.com/media/xT9IgEYXCNqPZnqMuY/giphy.gif)

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# **Общий вывод по проекту <font color= "black"> V2</font>**
#
# Евгений, спасибо за обратную связь, проверять твою работу было очень удобно🙏
#
# Ты молодец, тебе удалость:
#
# * Исправить оформление графиков
# * Переделать алгоритм поиска событий пересекающихся с праздниками
# * Добавить классический анализ воронки (все кроме графика)
# * Добавить обоснование выбора какой критерий будет применяться
# * Добавить наблюдение какой уровень значимости будет использован
# * Добавить формулировку гипотез
# * Переделать алгоритм создания таблиц `ta tb sa sb`
# * Переписать и дополнить выводы, где требуется
#
# Проект очень необычный, но при это очень полезный.
#
# Поздравляю с завершением этого проекта, надеюсь мои комментарии были полезны тебе 🥳
#
# **Желаю море впечатлений этим летом🌊 ты почти у цели**😉
#
# ![gif](https://media3.giphy.com/media/mJHSkWKziszrkcNJPo/giphy.gif?cid=ecf05e4751sqiwyupsnl7wcq220d4w5u5885lsimcajolzd2&rid=giphy.gif&ct=g)
